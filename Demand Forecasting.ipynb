# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read CSV file and make a Pandas Dataframe

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\MSDS\THESIS-I\DATASETS\Dataset4_DataCo SMART SUPPLY CHAIN FOR BIG DATA ANALYSIS1\DataCoSupplyChainDataset.csv', encoding= "latin-1")

# %%
df.head(5)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %% [markdown]
# ### Find Mean, Standard Deviation, Min value, Max value of the entire Dataframe

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %% [markdown]
# ### Find Types and the non null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %% [markdown]
# ### Number of Null values present in each feature

# %%
df.isna().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %% [markdown]
# ### Feature Extraction for working upon on Dataframe

# %%
features=['order date (DateOrders)','Sales','Order Item Discount','Order Item Quantity']

# %%
df=df[features]

# %%
df.head(5)
# Out:
#   order date (DateOrders)   Sales  Order Item Discount  Order Item Quantity
# 0         1/31/2018 22:56  327.75            13.110000                    1
# 1         1/13/2018 12:27  327.75            16.389999                    1
# 2         1/13/2018 12:06  327.75            18.030001                    1
# 3         1/13/2018 11:45  327.75            22.940001                    1
# 4         1/13/2018 11:24  327.75            29.500000                    1

# %% [markdown]
# ### Applying to Pandas DateTime format for easy access

# %%
df['order date (DateOrders)'] =  df['order date (DateOrders)'].apply(pd.to_datetime)

# %%
df.head(5)
# Out:
#   order date (DateOrders)   Sales  Order Item Discount  Order Item Quantity
# 0     2018-01-31 22:56:00  327.75            13.110000                    1
# 1     2018-01-13 12:27:00  327.75            16.389999                    1
# 2     2018-01-13 12:06:00  327.75            18.030001                    1
# 3     2018-01-13 11:45:00  327.75            22.940001                    1
# 4     2018-01-13 11:24:00  327.75            29.500000                    1

# %% [markdown]
# ### Sorting the records by date and their time

# %%
df = df.sort_values(by='order date (DateOrders)')

# %%
df.head(10)
# Out:
#        order date (DateOrders)       Sales  Order Item Discount  \
# 33833      2015-01-01 00:00:00  299.980011                60.00
# 77011      2015-01-01 00:21:00  199.990005                 6.00
# 109322     2015-01-01 00:21:00  250.000000                22.50
# 87884      2015-01-01 00:21:00  129.990005                22.10
# 114915     2015-01-01 01:03:00  199.919998                39.98
# 95938      2015-01-01 01:03:00  150.000000                27.00
# 63764      2015-01-01 01:03:00   49.980000                 9.00
# 96131      2015-01-01 01:03:00  299.950012                 3.00
# 114914     2015-01-01 01:24:00   99.959999                16.99
# 58046      2015-01-01 01:24:00  299.950012                 0.00
#
#         Order Item Quantity
# 33833                     1
# 77011                     1
# 109322                    5
# 87884                     1
# 114915                    4
# 95938                     3
# 63764                     2
# ...

# %% [markdown]
# ### Making column of Order date to Index

# %%
df.set_axis(df['order date (DateOrders)'], inplace=True)

# %%
df.drop(columns=['order date (DateOrders)'],inplace=True)

# %%
df.head(10)
# Out:
#                               Sales  Order Item Discount  Order Item Quantity
# order date (DateOrders)
# 2015-01-01 00:00:00      299.980011                60.00                    1
# 2015-01-01 00:21:00      199.990005                 6.00                    1
# 2015-01-01 00:21:00      250.000000                22.50                    5
# 2015-01-01 00:21:00      129.990005                22.10                    1
# 2015-01-01 01:03:00      199.919998                39.98                    4
# 2015-01-01 01:03:00      150.000000                27.00                    3
# 2015-01-01 01:03:00       49.980000                 9.00                    2
# 2015-01-01 01:03:00      299.950012                 3.00                    5
# 2015-01-01 01:24:00       99.959999                16.99                    2
# 2015-01-01 01:24:00      299.950012                 0.00                    5

# %%
df.tail()
# Out:
#                               Sales  Order Item Discount  Order Item Quantity
# order date (DateOrders)
# 2018-01-31 22:14:00      215.820007            53.959999                    1
# 2018-01-31 22:35:00      215.820007            43.160000                    1
# 2018-01-31 22:56:00      327.750000            13.110000                    1
# 2018-01-31 23:17:00       11.540000             0.630000                    1
# 2018-01-31 23:38:00       39.750000             4.770000                    1

# %% [markdown]
# ### Month-wise Aggregates

# %%
monthlysales = df.groupby([(df.index.year), (df.index.month)])['Sales'].sum().astype(int)

# %%
monthlydiscount = df.groupby([(df.index.year), (df.index.month)])['Order Item Discount'].sum().astype(int)

# %%
monthlyquantity = df.groupby([(df.index.year), (df.index.month)])['Order Item Quantity'].sum().astype(int)

# %% [markdown]
# ### Monthly Sales

# %%
print('Monthly Sales across the Years:')
print(monthlysales)
# Out:
# Monthly Sales across the Years:
# order date (DateOrders)  order date (DateOrders)
# 2015                     1                          1051590
#                          2                           927009
#                          3                          1051253
#                          4                          1014463
#                          5                          1050478
#                          6                          1024006
#                          7                          1038081
#                          8                          1029494
#                          9                          1018338
#                          10                         1049154
#                          11                         1029120
#                          12                         1057840
# 2016                     1                          1046308
#                          2                           968542
# ...

# %% [markdown]
# ### Monthly Discount

# %%
print('Monthly Discount across the Years:')
print(monthlydiscount)
# Out:
# Monthly Discount across the Years:
# order date (DateOrders)  order date (DateOrders)
# 2015                     1                          106209
#                          2                           93998
#                          3                          107204
#                          4                          102460
#                          5                          106539
#                          6                          103765
#                          7                          105145
#                          8                          104303
#                          9                          103817
#                          10                         106024
#                          11                         104518
#                          12                         107315
# 2016                     1                          106025
#                          2                           98427
# ...

# %% [markdown]
# ### Monthly Quantity

# %%
print('Monthly Quantity across the Years:')
print(monthlyquantity)
# Out:
# Monthly Quantity across the Years:
# order date (DateOrders)  order date (DateOrders)
# 2015                     1                          11854
#                          2                          10438
#                          3                          12062
#                          4                          11287
#                          5                          11902
#                          6                          11203
#                          7                          11800
#                          8                          11612
#                          9                          11366
#                          10                         11703
#                          11                         11463
#                          12                         11790
# 2016                     1                          11597
#                          2                          10765
#                          3                          11349
# ...

# %% [markdown]
# ### Display in single Dataframe

# %%
totalsales=pd.DataFrame(monthlysales)
totaldiscount=pd.DataFrame(monthlydiscount)
totalquantitiy=pd.DataFrame(monthlyquantity)

# %%
total=totalsales.join(totaldiscount)

# %%
total=total.join(totalquantitiy)

# %%
total.head()
# Out:
#                                                    Sales  Order Item Discount  \
# order date (DateOrders) order date (DateOrders)
# 2015                    1                        1051590               106209
#                         2                         927009                93998
#                         3                        1051253               107204
#                         4                        1014463               102460
#                         5                        1050478               106539
#
#                                                  Order Item Quantity
# order date (DateOrders) order date (DateOrders)
# 2015                    1                                      11854
#                         2                                      10438
#                         3                                      12062
#                         4                                      11287
# ...

# %%
y = total.index.get_level_values(0)
m = total.index.get_level_values(1)

# %%
total['Date'] = pd.to_datetime(y* 10000 + m * 100 + 1, format="%Y%m%d")

# %%
total.set_index('Date', append=True, inplace=True)

# %%
total=total.droplevel(0)

# %%
total=total.droplevel(0)

# %%
total.head(10)
# Out:
#               Sales  Order Item Discount  Order Item Quantity
# Date
# 2015-01-01  1051590               106209                11854
# 2015-02-01   927009                93998                10438
# 2015-03-01  1051253               107204                12062
# 2015-04-01  1014463               102460                11287
# 2015-05-01  1050478               106539                11902
# 2015-06-01  1024006               103765                11203
# 2015-07-01  1038081               105145                11800
# 2015-08-01  1029494               104303                11612
# 2015-09-01  1018338               103817                11366
# 2015-10-01  1049154               106024                11703
